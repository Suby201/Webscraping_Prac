# %% [markdown]
# 과제 1번

# %%
# reqeusts, bs4 import
import requests
import bs4

# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

url = "https://news.daum.net/economy"
print(url)

req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
}

res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code)

if res.ok:
    # 응답 (response)에서 text 추출
    res.encoding = "utf-8"
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    # CSS 선택자
    soup.select("div.cont_thumb strong.tit_txt")
    # print(soup.select("div.sa_text a[href*='mnews/article']"))

    # <a> 태그 리스트 순회하기
    li_tag_list = soup.select("ul.list_newsheadline2 li")
    print(type(li_tag_list), len(li_tag_list))


    for li_tag in li_tag_list:
        a_tag = li_tag.find('a')
        link = a_tag['href']
        strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
        title = strong_tag.text
        print(link)
        print(title)
else:
    print(f"error code={res.status_code}")
# Out:
# https://news.daum.net/economy
# <class 'requests.models.Response'>
# 200
# <class 'bs4.element.ResultSet'> 9
# https://v.daum.net/v/20250409170308062
# "차준환이 왜 여기서 나와?"… 푸조와 긴밀한 '상관관계'
# https://v.daum.net/v/20250409165454716
# 美 국채 발작에 자금시장 대혼란··· "원달러 1500원도 위험"
# https://v.daum.net/v/20250409165324633
# '관세맨' 트럼프 "동맹국 협상 우선"...EU와 손잡는 중국 [데일리 아시아]
# https://v.daum.net/v/20250409163907118
# 가맹점 매출 타 소상공보다 안정적…2023년 평균 매출 3억5천만원
# https://v.daum.net/v/20250409163538983
# “청년보다 더 위험하다”...50대 고용률 12개월 연속 감소.
# https://v.daum.net/v/20250409160101623
# 수요 침체서 겨우 살아나나 싶었는데…IT도 미국발 침체 우려
# https://v.daum.net/v/20250409155045087
# 비명 질러도 레버리지 ‘몰빵’…폭락장이 3배 더 아픈 서학개미들
# https://v.daum.net/v/20250409152121807
# 美상호관세 본게임 시작…'조선·LNG·무역균형' 협상카드 "최선의 선택지"
# https://v.daum.net/v/20250409150221908
# 美 관세폭탄·전기차 캐즘에도… 기아, '수익 방어' 자신감

# %% [markdown]
# 과제 2번

# %%
# reqeusts, bs4 import
import requests
import bs4

# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

section_dict = {
    "기후/환경": "climate",
    "사회": "society",
    "경제": "economy",
    "정치": "politics",
    "국재": "world",
    "문화": "culture",
    "생활": "life",
    "IT/과학": "tech",
    "인물": "people",
}


# 함수선언
def print_news(section_name):
    section = section_dict[section_name]
    url = f"https://news.daum.net/{section}"

    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
    }
    print(f'=======>  {url}  {section_name} 뉴스 <=======')
    res = requests.get(url, headers=req_header)

    if res.ok:
        # 응답 (response)에서 text 추출
        res.encoding = "utf-8"
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")

        li_tag_list = soup.select("ul.list_newsheadline2 li")


        for li_tag in li_tag_list:
            a_tag = li_tag.find('a')
            link = a_tag['href']
            strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
            title = strong_tag.text
            print(link)
            print(title)
    else:
        print(f"error code={res.status_code}")


# 함수호출
print_news("경제")
print_news("사회")
# Out:
# =======>  https://news.daum.net/economy  경제 뉴스 <=======
# https://v.daum.net/v/20250408171205288
# 이러다 진짜 전쟁...트럼프 '104% 관세'에 끝까지 싸운다는 中 [데일리 아시아]
# https://v.daum.net/v/20250408161553109
# 트럼프발 주가폭락에 동아 "경제적 핵전쟁" 조선 "금융위기 후 최악"
# https://v.daum.net/v/20250408160526681
# 공황과 격변의 판도라 박스가 열리다
# https://v.daum.net/v/20250408154329660
# 해외서 발 뺀 이중항체, 韓 기업들이 이끈다
# https://v.daum.net/v/20250408153003030
# 탄핵 끝났는데 韓경제 ‘봄’은 언제 오나…박근혜 때와 다른 이유
# https://v.daum.net/v/20250408152923007
# 경상수지 흑자행진에도… 한은 “美 관세에 불확실성 확대”
# https://v.daum.net/v/20250408144527816
# 국제유가 하락에 흔들리는 정유업계…실적 먹구름 짙어진다
# https://v.daum.net/v/20250408140753767
# 조양호 한진그룹 선대회장 6주기… ‘45년 항공산업’ 리더십 재조명
# https://v.daum.net/v/20250408140302580
# 미국 최대 은행이 "여성 경영인이 경제 원동력"이라 말한 이유
# =======>  https://news.daum.net/society  사회 뉴스 <=======
# https://v.daum.net/v/20250408172027551
# 엇갈린 곽종근과 김현태…‘공익제보자 보호법’ 강화 목소리 커진다
# https://v.daum.net/v/20250408172004542
# 이진숙 ‘일하지 말란 거냐’ 강변에 법원은 이렇게 대답했다
# https://v.daum.net/v/20250408170525058
# 진실화해위 노조, 조선일보 '인민군 서울대병원 학살' 보도 명예훼손 고발
# https://v.daum.net/v/20250408165701732
# "창원시 소송 몰아주기 의혹, 행정심판으로 밝히겠다"
# https://v.daum.net/v/20250408165107520
# 미얀마 이재민 곁에 선 한국 의사 13인의 땀방울, 지옥 같은 땅에서 연꽃을 피웠다
# https://v.daum.net/v/20250408164221130
# “롤러코스터에서 내리고 싶어요”···트럼프 관세정책에 떠는 사람들
# https://v.daum.net/v/20250408164010033
# "마지막 관람?" 청와대 관람객 폭증 이유 봤더니 外
# https://v.daum.net/v/20250408163627912
# 울진군, 복지 핵심 가치 실현 앞장…다양한 사업 추진
# https://v.daum.net/v/20250408163611904
# 대선일 확정에 "청와대 빨리 구경하자"…관람객 2배 늘었다

# %% [markdown]
# 과제 3번

# %%
# reqeusts, bs4 import
import requests
import bs4

# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

section_dict = {
    "최신" : "0100",
    "정치" : "0200",
    "경제" : "0300",
    "사회" : "0400",
    "세계" : "0500",
    "IT/과학" : "0600"
}

def print_news(section_name):
    section = section_dict[section_name]
    if section=='0100':
        url = f"https://news.nate.com/recent?mid=n{section}"
    else:
        url = f"https://news.nate.com/section?mid=n{section}"

    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
    }
    print(f'=======>  {url}  {section_name} 뉴스 <=======')
    res = requests.get(url, headers=req_header)
    
    if res.ok:
        html = res.text
        soup = BeautifulSoup(html, "html.parser")
        a_tag_list = soup.select("div.mlt01 a")

        for a_tag in a_tag_list:
            link = a_tag['href']
            h2_tag = a_tag.select_one('span.tb h2.tit')
            title = h2_tag.text
            print(f'https:{link}')
            print(title)

text = input('최신, 정치, 경제, 사회, 세계, IT/과학 중 하나를 입력하시오')
print_news(text)
# Out:
# =======>  https://news.nate.com/section?mid=n0200  정치 뉴스 <=======
# https://news.nate.com/view/20250409n27024?mid=n0200
# 권성동 "윤석열·이재명 동시 퇴장이 시대의 명령"
# https://news.nate.com/view/20250409n27152?mid=n0200
# 명태균·김영선, 구속 145일 만에 풀려난다…"주거지 제한, 보석금 5000만원 조건"
# https://news.nate.com/view/20250409n27495?mid=n0200
# 노무현에 따졌던 '그 검사' 다시 돌아왔다…이완규 "사퇴 거부"
# https://news.nate.com/view/20250409n27309?mid=n0200
# 오세훈, 시장직 달고 대권 도전…"마지막까지 시정 책임"
# https://news.nate.com/view/20250409n22374?mid=n0200
# '대선 시동' 이재명, 8년 만의 단독 저서 '결국 국민이 합니다' 출간
# https://news.nate.com/view/20250409n26089?mid=n0200
# 우원식 "인사청문 요청 접수 않겠다"…법조계 보이콧엔 회의적
# https://news.nate.com/view/20250409n23624?mid=n0200
# 국힘 대선 후보군 벌써 15명…'절대 강자' 없자 너도나도 "출마"
# https://news.nate.com/view/20250409n23037?mid=n0200
# 이철우 "이재명 이길 새 인물…새로운 박정희 되겠다"
# https://news.nate.com/view/20250409n16582?mid=n0200
# 김두관 "국회 분원·대통령실 부지 있는 세종…수도 이전 충분히 가능"
# https://news.nate.com/view/20250409n21665?mid=n0200
# 김문수 "위대한 대한민국 이룰 것"…현충원 찾아 본격 대선 모드
# https://news.nate.com/view/20250409n21326?mid=n0200
# 김동연이 밝힌 '3무3유 선거운동'…"국민이 계파이고 조직"
# https://news.nate.com/view/20250409n20281?mid=n0200
# '막차' 타고 대구 간 이준석…"이재명 대권 목전…이기는 선택 되겠다"
# https://news.nate.com/view/20250409n19177?mid=n0200
# 황교안, 국힘 탈당 대선 출마 "부정선거 척결…尹 응원 받아"
# https://news.nate.com/view/20250409n21218?mid=n0200
# '한덕수 폭탄'에 우원식 "개헌 논의 미루자"…개헌 동시투표 제안 철회
# https://news.nate.com/view/20250409n21478?mid=n0200
# [단독] 한동훈, 울산서 대권 행보 시작…"경제가 가장 중요"
